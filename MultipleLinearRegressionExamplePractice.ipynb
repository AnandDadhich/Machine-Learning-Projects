# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\dell\\Desktop\\Machine Learning\\50_Startups.csv")

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
df['R&D Spend'].value_counts().head()
# Out:
# 0.00         2
# 123334.88    1
# 165349.20    1
# 38558.51     1
# 46014.02     1
# Name: R&D Spend, dtype: int64

# %%
df['State'].value_counts().head()
# Out:
# California    17
# New York      17
# Florida       16
# Name: State, dtype: int64

# %%
df['Marketing Spend'].value_counts().head()
# Out:
# 0.00         3
# 46085.25     1
# 383199.62    1
# 107138.38    1
# 205517.64    1
# Name: Marketing Spend, dtype: int64

# %%
df['Profit'].value_counts().head()
# Out:
# 118474.03    1
# 69758.98     1
# 81229.06     1
# 101004.64    1
# 124266.90    1
# Name: Profit, dtype: int64

# %%
sns.distplot(df['Profit'],bins=100)
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(df['Marketing Spend'],bins=100)
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(df['R&D Spend'],bins=100)
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(df['Administration'],bins=100)
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.pairplot(data=df)

# %%
x=df.drop(['State','Profit'],axis=1)
y=df['Profit']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression().fit(x_train,y_train)

# %%
pred=model.predict(x_test)

# %%
fig=plt.figure(figsize=(15,8),dpi=300)
plt.scatter(y_test,pred)
plt.xlabel("Expected Result")
plt.ylabel("Actual Result")
plt.title("Linear Regression")
plt.grid()

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
print(mean_absolute_error(y_test,pred))
# Out:
# 6979.1522523704025

# %%
print(mean_squared_error(y_test,pred))
# Out:
# 80926321.22295167
