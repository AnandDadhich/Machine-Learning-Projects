# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
df=pd.read_csv("C:\\Users\\dell\\Desktop\\Machine Learning\\Ecommerce Customers.csv")

# %%
df.head()
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1     4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3   1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# ...

# %%
df['Email'].value_counts()
# Out:
# marshchristopher@zimmerman-villegas.com    1
# cwilson@hotmail.com                        1
# bhamilton@shaw.biz                         1
# oolson@collins.com                         1
# erik46@hotmail.com                         1
# ellen24@anthony.com                        1
# efoster@williamson-boyd.org                1
# teresaallen@hill-leach.info                1
# gstrong@hotmail.com                        1
# dale88@hotmail.com                         1
# jstark@anderson.com                        1
# prussell@lopez.com                         1
# millerrachel@gallagher-nichols.com         1
# douglas95@yahoo.com                        1
# francesjohnson@lee.com                     1
# nicolegay@jennings.com                     1
# amanda03@yahoo.com                         1
# thomas22@yahoo.com                         1
# christopher66@hotmail.com                  1
# brenda25@gmail.com                         1
# jjones@yahoo.com                           1
# ...

# %%
df['Avatar'].value_counts()
# Out:
# GreenYellow             7
# Cyan                    7
# SlateBlue               7
# CadetBlue               7
# Teal                    7
# BlueViolet              6
# DarkGoldenRod           6
# Bisque                  6
# DarkSeaGreen            6
# LightSkyBlue            6
# Turquoise               6
# Purple                  6
# SaddleBrown             6
# DarkViolet              6
# OliveDrab               6
# DeepPink                6
# Aqua                    6
# PeachPuff               6
# Tomato                  6
# Wheat                   6
# Orange                  6
# Moccasin                6
# MediumSpringGreen       5
# AntiqueWhite            5
# SandyBrown              5
# Olive                   5
# White                   5
# Thistle                 5
# LemonChiffon            5
# BlanchedAlmond          5
#                        ..
# Silver                  2
# DarkSlateGray           2
# Khaki                   2
# FireBrick               2
# ...

# %%
df['Address'].value_counts()
# Out:
# PSC 2490, Box 2120\nAPO AE 15445-2876                                   1
# 05302 Dunlap Ferry\nNew Stephaniehaven, MP 42268                        1
# 395 Summers Courts Apt. 413\nCoopermouth, IA 21205-1079                 1
# 120 Micheal Fort Apt. 762\nEast Patrickbury, WY 65946                   1
# 73469 Baker Forest Apt. 550\nAllenbury, TX 63791                        1
# 5379 Rhonda Prairie Apt. 696\nBrownland, WA 87027                       1
# 410 Gonzalez Corners Apt. 187\nEast Stephenport, VT 22771               1
# 721 Robert Viaduct Apt. 052\nLake Olivia, MO 93807                      1
# 354 Sanchez Wall Suite 884\nJuliabury, VI 39735                         1
# 399 Jeremy Skyway Suite 377\nNorth Keithville, IL 55074                 1
# USNS Jacobs\nFPO AE 71507-1312                                          1
# 022 Taylor Mews Suite 692\nHallberg, NJ 53614                           1
# 811 Maria Run\nSanchezville, MI 04953                                   1
# ...

# %%
df['Avatar'].value_counts()
# Out:
# GreenYellow             7
# Cyan                    7
# SlateBlue               7
# CadetBlue               7
# Teal                    7
# BlueViolet              6
# DarkGoldenRod           6
# Bisque                  6
# DarkSeaGreen            6
# LightSkyBlue            6
# Turquoise               6
# Purple                  6
# SaddleBrown             6
# DarkViolet              6
# OliveDrab               6
# DeepPink                6
# Aqua                    6
# PeachPuff               6
# Tomato                  6
# Wheat                   6
# Orange                  6
# Moccasin                6
# MediumSpringGreen       5
# AntiqueWhite            5
# SandyBrown              5
# Olive                   5
# White                   5
# Thistle                 5
# LemonChiffon            5
# BlanchedAlmond          5
#                        ..
# Silver                  2
# DarkSlateGray           2
# Khaki                   2
# FireBrick               2
# ...

# %%
df["Avg. Session Length"].value_counts()
# Out:
# 32.653181    1
# 31.445972    1
# 32.454553    1
# 33.540479    1
# 32.745150    1
# 32.903454    1
# 32.077590    1
# 32.922611    1
# 33.256335    1
# 32.491447    1
# 34.338729    1
# 31.123974    1
# 32.030550    1
# 33.503705    1
# 32.887105    1
# 33.144234    1
# 31.816428    1
# 34.336677    1
# 32.654622    1
# 33.235607    1
# 33.785207    1
# 32.125387    1
# 33.605799    1
# 32.533797    1
# 33.398260    1
# 33.501370    1
# 34.200539    1
# 34.555768    1
# 34.713317    1
# 33.762069    1
#             ..
# 31.169507    1
# 34.568681    1
# 33.369381    1
# 33.358398    1
# 32.335990    1
# 32.903251    1
# 32.215527    1
# 33.026420    1
# 33.154255    1
# 33.503087    1
# 34.318927    1
# 33.217188    1
# 34.385820    1
# 32.510218    1
# 34.357196    1
# 34.102279    1
# 31.260647    1
# 33.674027    1
# 31.904857    1
# 32.609283    1
# 32.789773    1
# 34.002071    1
# 33.330673    1
# 34.140393    1
# 33.142079    1
# 34.083663    1
# 33.356874    1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
# Email                   500 non-null object
# Address                 500 non-null object
# Avatar                  500 non-null object
# Avg. Session Length     500 non-null float64
# Time on App             500 non-null float64
# Time on Website         500 non-null float64
# Length of Membership    500 non-null float64
# Yearly Amount Spent     500 non-null float64
# dtypes: float64(5), object(3)
# memory usage: 31.3+ KB

# %%
df.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %%
a=df['Time on Website'].unique()

# %%
a.count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-f11c6a8bc4f8> in <module>()
# ----> 1 a.count()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'count'

# %%
df['Time on Website'].unique()
# Out:
# array([39.57766802, 37.26895887, 37.11059744, 36.72128268, 37.5366533 ,
#        34.47687763, 36.68377615, 37.37335886, 37.53449734, 37.14516822,
#        37.22580613, 37.08792607, 37.42021558, 36.1446667 , 36.61995708,
#        36.21376309, 34.89409275, 38.38513659, 38.24411459, 37.1905038 ,
#        37.60779252, 37.44102134, 38.73400629, 36.77260376, 37.63575588,
#        37.73852495, 36.43064962, 37.85177917, 35.29308775, 37.27781174,
#        36.16364817, 35.62244242, 35.69417499, 38.87804051, 35.36862633,
#        38.768641  , 36.76572236, 37.0443614 , 37.38831487, 36.37147981,
#        37.53429101, 37.49669015, 37.14286198, 36.88808605, 36.11243501,
#        39.13109673, 37.33544589, 36.46200326, 36.58272777, 36.5944567 ,
#        37.78026469, 37.26687826, 37.4534051 , 35.9334493 , 38.46832111,
#        35.25224202, 39.25293095, 36.17312563, 36.81401056, 37.27122169,
#        38.05260975, 36.49399255, 37.99702801, 37.40874848, 36.60077705,
# ...

# %%
df['Time on Website'].nunique()
# Out:
# 500

# %%
df['Email'].value_counts()
# Out:
# marshchristopher@zimmerman-villegas.com    1
# cwilson@hotmail.com                        1
# bhamilton@shaw.biz                         1
# oolson@collins.com                         1
# erik46@hotmail.com                         1
# ellen24@anthony.com                        1
# efoster@williamson-boyd.org                1
# teresaallen@hill-leach.info                1
# gstrong@hotmail.com                        1
# dale88@hotmail.com                         1
# jstark@anderson.com                        1
# prussell@lopez.com                         1
# millerrachel@gallagher-nichols.com         1
# douglas95@yahoo.com                        1
# francesjohnson@lee.com                     1
# nicolegay@jennings.com                     1
# amanda03@yahoo.com                         1
# thomas22@yahoo.com                         1
# christopher66@hotmail.com                  1
# brenda25@gmail.com                         1
# jjones@yahoo.com                           1
# ...

# %%
df['Yearly Amount Spent'].value_counts()
# Out:
# 436.515606    1
# 547.125932    1
# 469.310861    1
# 489.812488    1
# 506.423860    1
# 357.591439    1
# 503.978379    1
# 461.920877    1
# 549.860590    1
# 426.154548    1
# 555.068394    1
# 357.857984    1
# 449.070319    1
# 463.923513    1
# 443.441860    1
# 376.336901    1
# 502.771075    1
# 308.527747    1
# 460.061277    1
# 456.469510    1
# 479.614812    1
# 571.471034    1
# 486.163799    1
# 542.412477    1
# 567.475011    1
# 392.497399    1
# 482.830986    1
# 451.575685    1
# 573.306222    1
# 447.369027    1
#              ..
# 468.445737    1
# 576.477607    1
# 689.235700    1
# 587.574799    1
# 744.221867    1
# 505.113344    1
# 519.372977    1
# 660.425184    1
# 700.917092    1
# 553.601535    1
# 524.797628    1
# 554.722084    1
# 544.779864    1
# 434.144202    1
# 393.857371    1
# 521.883573    1
# 483.159721    1
# 511.979860    1
# 408.216902    1
# 666.125592    1
# 563.672873    1
# 538.941975    1
# 444.053827    1
# 493.180216    1
# ...

# %%
x=df.drop(['Address','Avatar',"Email",'Yearly Amount Spent'],axis=1)
y=df['Yearly Amount Spent']

# %%
import seaborn as sns

# %%
sns.distplot(df['Yearly Amount Spent'],bins=100)
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(df['Avg. Session Length'],bins=100)
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(df['Yearly Amount Spent'],bins=100)
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(df['Length of Membership'],bins=100)
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
df
# Out:
#                                Email  \
# 0          mstephenson@fernandez.com
# 1                  hduke@hotmail.com
# 2                   pallen@yahoo.com
# 3            riverarebecca@gmail.com
# 4      mstephens@davidson-herman.com
# 5             alvareznancy@lucas.biz
# 6              katherine20@yahoo.com
# 7                 awatkins@yahoo.com
# 8        vchurch@walter-martinez.com
# 9                   bonnie69@lin.biz
# 10             andrew06@peterson.com
# 11            ryanwerner@freeman.biz
# 12                 knelson@gmail.com
# 13             wrightpeter@yahoo.com
# 14             taylormason@gmail.com
# 15               jstark@anderson.com
# 16               wjennings@gmail.com
# 17          rebecca45@hale-bauer.biz
# 18           alejandro75@hotmail.com
# 19            samuel46@love-west.net
# 20                 megan33@gmail.com
# 21                 agolden@yahoo.com
# 22             vstafford@hotmail.com
# 23   denise22@hernandez-townsend.com
# ...

# %%
sns.pairplot(df)

# %%
x.columns
# Out:
# Index(['Avg. Session Length', 'Time on App', 'Time on Website',
#        'Length of Membership'],
#       dtype='object')

# %%
y
# Out:
# 0      587.951054
# 1      392.204933
# 2      487.547505
# 3      581.852344
# 4      599.406092
# 5      637.102448
# 6      521.572175
# 7      549.904146
# 8      570.200409
# 9      427.199385
# 10     492.606013
# 11     522.337405
# 12     408.640351
# 13     573.415867
# 14     470.452733
# 15     461.780742
# 16     457.847696
# 17     407.704548
# 18     452.315675
# 19     605.061039
# 20     534.705744
# 21     419.938775
# 22     436.515606
# 23     519.340989
# 24     700.917092
# 25     423.179992
# 26     619.895640
# 27     486.838935
# 28     529.537665
# 29     554.722084
#           ...
# 470    424.728774
# 471    541.049831
# 472    469.383146
# 473    444.545550
# 474    492.556834
# 475    535.321610
# 476    408.958336
# 477    487.555458
# 478    487.646232
# 479    402.167122
# 480    551.023002
# 481    497.389558
# 482    494.638610
# 483    479.247417
# 484    462.656519
# 485    515.502480
# 486    576.477607
# 487    357.857984
# 488    597.739879
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 400 entries, 249 to 102
# Data columns (total 4 columns):
# Avg. Session Length     400 non-null float64
# Time on App             400 non-null float64
# Time on Website         400 non-null float64
# Length of Membership    400 non-null float64
# dtypes: float64(4)
# memory usage: 15.6 KB

# %%
x_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 361 to 15
# Data columns (total 4 columns):
# Avg. Session Length     100 non-null float64
# Time on App             100 non-null float64
# Time on Website         100 non-null float64
# Length of Membership    100 non-null float64
# dtypes: float64(4)
# memory usage: 3.9 KB

# %%
y_train.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-96-6e837eca3a7a> in <module>()
# ----> 1 y_train.info()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'info'

# %%
y_test()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-97-7698e8fffa5c> in <module>()
# ----> 1 y_test()
#
# TypeError: 'Series' object is not callable

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression().fit(x_train,y_train)

# %%
df
# Out:
#                                Email  \
# 0          mstephenson@fernandez.com
# 1                  hduke@hotmail.com
# 2                   pallen@yahoo.com
# 3            riverarebecca@gmail.com
# 4      mstephens@davidson-herman.com
# 5             alvareznancy@lucas.biz
# 6              katherine20@yahoo.com
# 7                 awatkins@yahoo.com
# 8        vchurch@walter-martinez.com
# 9                   bonnie69@lin.biz
# 10             andrew06@peterson.com
# 11            ryanwerner@freeman.biz
# 12                 knelson@gmail.com
# 13             wrightpeter@yahoo.com
# 14             taylormason@gmail.com
# 15               jstark@anderson.com
# 16               wjennings@gmail.com
# 17          rebecca45@hale-bauer.biz
# 18           alejandro75@hotmail.com
# 19            samuel46@love-west.net
# 20                 megan33@gmail.com
# 21                 agolden@yahoo.com
# 22             vstafford@hotmail.com
# 23   denise22@hernandez-townsend.com
# ...

# %%
p=model.predict(x_test)

# %%
fig=plt.figure(figsize=(15,8),dpi=300)
plt.scatter(y_test,p)
plt.xlabel("Expected Result")
plt.ylabel("Actual Result")
plt.title("Linear Regression")
plt.grid()
